# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('healthcare_dataset.csv')

# %%
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# 1   UnitedHealthcare    47304.064845          404      Emergency
# 2           Medicare    36874.896997          292      Emergency
# 3           Medicare    23303.322092          480         Urgent
# 4   UnitedHealthcare    18086.344184          477         Urgent
#
#   Discharge Date   Medication  Test Results
# 0     2022-12-01      Aspirin  Inconclusive
# 1     2023-06-15      Lipitor        Normal
# 2     2019-02-08      Lipitor        Normal
# 3     2020-05-03   Penicillin      Abnormal
# 4     2021-08-02  Paracetamol        Normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
for columns in df.columns:
    uniques=df[columns].unique()
    print(columns)
    print(uniques)
# Out:
# Name
# ['Tiffany Ramirez' 'Ruben Burns' 'Chad Byrd' ... 'Christopher Martinez'
#  'Amanda Duke' 'Eric King']
# Age
# [81 35 61 49 51 41 82 55 33 39 45 23 85 72 65 32 64 66 80 79 54 26 70 74
#  56 37 78 83 30 19 46 48 34 84 47 60 57 21 27 68 31 42 71 38 28 43 69 73
#  67 44 20 59 76 40 36 29 53 77 24 75 25 62 52 50 22 63 58 18]
# Gender
# ['Female' 'Male']
# Blood Type
# ['O-' 'O+' 'B-' 'AB+' 'A+' 'AB-' 'A-' 'B+']
# Medical Condition
# ['Diabetes' 'Asthma' 'Obesity' 'Arthritis' 'Hypertension' 'Cancer']
# Date of Admission
# ['2022-11-17' '2023-06-01' '2019-01-09' ... '2020-07-03' '2022-02-19'
#  '2022-07-29']
# Doctor
# ['Patrick Parker' 'Diane Jackson' 'Paul Baker' ... 'Robert Nicholson'
#  'Jamie Lewis' 'Tasha Avila']
# Hospital
# ['Wallace-Hamilton' 'Burke, Griffin and Cooper' 'Walton LLC' ...
#  'Nash-Krueger' 'Wilson-Lyons' 'Torres, Young and Stewart']
# Insurance Provider
# ['Medicare' 'UnitedHealthcare' 'Aetna' 'Cigna' 'Blue Cross']
# Billing Amount
# [37490.98336353 47304.06484548 36874.89699661 ... 49559.20290467
#  25236.34476098 37223.96586473]
# Room Number
# [146 404 292 480 477 180 161 384 215 310 306 126 444 492 120 315 475 125
#  366 238 364 130 293 379 298 392 162 456 197 247 228 137 192 258 219 414
#  110 465 469 182 119 388 412 359 186 437 132 271 361 303 317 439 153 438
#  380 194 199 301 223 410 205 134 407 188 213 405 358 147 115 436 263 493
#  460 356 142 139 482 141 397 347 245 143 108 268 176 462 484 329 335 201
#  309 389 217 299 275 181 401 214 267 211 184 140 416 179 289 350 104 220
#  464 419 445 398 336 413 145 148 432 430 406 295 175 409 424 168 136 459
#  261 257 170 451 372 202 394 264 279 260 499 452 365 340 360 290 103 187
#  378 334 470 252 450 106 259 344 489 276 155 455 425 400 127 333 443 129
#  164 486 440 265 193 222 488 472 391 230 322 272 154 236 375 221 244 287
#  243 370 237 234 458 226 478 204 196 294 297 280 374 216 135 225 152 270
#  454 442 189 487 485 218 111 105 362 497 420 483 288 133 114 253 286 109
#  390 207 411 324 357 283 471 274 353 311 490 368 284 242 209 433 116 278
#  249 498 240 107 383 338 262 496 447 246 305 479 363 239 158 369 229 403
#  349 476 144 330 291 325 224 386 428 174 101 382 435 235 474 467 118 206
#  233 269 422 441 320 173 277 423 112 304 300 227 121 461 302 266 417 231
#  171 150 323 457 449 418 151 195 332 183 312 172 285 250 494 354 210 308
#  385 124 190 163 339 203 355 500 212 415 254 381 131 191 178 326 138 241
#  481 313 156 402 248 331 341 495 208 377 343 427 296 165 200 123 468 273
#  396 351 395 319 393 491 232 376 473 185 429 453 348 337 255 434 463 102
#  316 345 399 314 408 159 251 157 169 387 448 431 149 282 198 307 281 373
#  371 426 177 352 446 421 321 256 167 122 342 113 466 346 128 160 117 328
#  367 318 327 166]
# Admission Type
# ['Elective' 'Emergency' 'Urgent']
# Discharge Date
# ['2022-12-01' '2023-06-15' '2019-02-08' ... '2023-01-02' '2019-05-23'
#  '2023-11-27']
# Medication
# ['Aspirin' 'Lipitor' 'Penicillin' 'Paracetamol' 'Ibuprofen']
# Test Results
# ['Inconclusive' 'Normal' 'Abnormal']

# %%
map_1={'Male':0,'Female':1}
df['Gender']=df['Gender'].map(map_1)
map_2={'O-':0, 'O+':1, 'B-':2,'AB+':3, 'A+':4, 'AB-':5,'A-':6,'B+':7}
df['Blood Type']=df['Blood Type'].map(map_2)
map_3={'Diabetes':0,'Asthma':1 ,'Obesity':2, 'Arthritis':3, 'Hypertension':4, 'Cancer':5}
df['Medical Condition']=df['Medical Condition'].map(map_3)
map_4={'Medicare':0, 'UnitedHealthcare':1, 'Aetna':2,'Cigna':3, 'Blue Cross':4}
df['Insurance Provider']=df['Insurance Provider'].map(map_4)
map_5={'Aspirin':0, 'Lipitor':1, 'Penicillin':2,'Paracetamol':3 ,'Ibuprofen':4}
df['Medication']=df['Medication'].map(map_5)
map_6={'Inconclusive':0,'Normal':1, 'Abnormal':2}
df['Test Results']=df['Test Results'].map(map_6)
map_7={'Elective':0 ,'Emergency':1 ,'Urgent':2}
df['Admission Type']=df['Admission Type'].map(map_7)
df.head()
# Out:
#                   Name  Age  Gender  Blood Type  Medical Condition  \
# 0      Tiffany Ramirez   81       1           0                  0
# 1          Ruben Burns   35       0           1                  1
# 2            Chad Byrd   61       0           2                  2
# 3    Antonio Frederick   49       0           2                  1
# 4  Mrs. Brandy Flowers   51       0           0                  3
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#    Insurance Provider  Billing Amount  Room Number  Admission Type  \
# 0                   0    37490.983364          146               0
# 1                   1    47304.064845          404               1
# 2                   0    36874.896997          292               1
# 3                   0    23303.322092          480               2
# 4                   1    18086.344184          477               2
#
#   Discharge Date  Medication  Test Results
# 0     2022-12-01           0             0
# 1     2023-06-15           1             1
# 2     2019-02-08           1             1
# 3     2020-05-03           2             2
# 4     2021-08-02           3             1

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  int64
#  3   Blood Type          10000 non-null  int64
#  4   Medical Condition   10000 non-null  int64
#  5   Date of Admission   10000 non-null  datetime64[ns]
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  int64
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  int64
#  12  Discharge Date      10000 non-null  datetime64[ns]
#  13  Medication          10000 non-null  int64
#  14  Test Results        10000 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# sns.scatterplot(x='Doctor',y='Test Results',data=df)

# %%
# sns.scatterplot(x='Hospital',y='Test Results',data=df)

# %%
# d1=df.groupby('Hospital',as_index=False)['Test Results'].sum()
# d1

# %%
# sns.scatterplot(x='Hospital',y='Test Results',data=d1)

# %%
df=df.drop(columns=['Hospital','Name','Doctor'])
df.head()
# Out:
#    Age  Gender  Blood Type  Medical Condition Date of Admission  \
# 0   81       1           0                  0        2022-11-17
# 1   35       0           1                  1        2023-06-01
# 2   61       0           2                  2        2019-01-09
# 3   49       0           2                  1        2020-05-02
# 4   51       0           0                  3        2021-07-09
#
#    Insurance Provider  Billing Amount  Room Number  Admission Type  \
# 0                   0    37490.983364          146               0
# 1                   1    47304.064845          404               1
# 2                   0    36874.896997          292               1
# 3                   0    23303.322092          480               2
# 4                   1    18086.344184          477               2
#
#   Discharge Date  Medication  Test Results
# 0     2022-12-01           0             0
# 1     2023-06-15           1             1
# 2     2019-02-08           1             1
# 3     2020-05-03           2             2
# 4     2021-08-02           3             1

# %%
df['Billing Amount']=df['Billing Amount'].astype(int)
df
# Out:
#       Age  Gender  Blood Type  Medical Condition Date of Admission  \
# 0      81       1           0                  0        2022-11-17
# 1      35       0           1                  1        2023-06-01
# 2      61       0           2                  2        2019-01-09
# 3      49       0           2                  1        2020-05-02
# 4      51       0           0                  3        2021-07-09
# ...   ...     ...         ...                ...               ...
# 9995   83       0           4                  2        2022-07-29
# 9996   47       1           3                  3        2022-01-06
# 9997   54       0           2                  3        2022-07-01
# 9998   84       0           4                  3        2020-02-06
# 9999   20       0           2                  3        2023-03-22
#
#       Insurance Provider  Billing Amount  Room Number  Admission Type  \
# 0                      0           37490          146               0
# 1                      1           47304          404               1
# 2                      0           36874          292               1
# 3                      0           23303          480               2
# 4                      1           18086          477               2
# ...                  ...             ...          ...             ...
# 9995                   1           39606          110               0
# 9996                   4            5995          244               1
# 9997                   4           49559          312               0
# 9998                   1           25236          420               2
# 9999                   2           37223          290               1
#
#      Discharge Date  Medication  Test Results
# 0        2022-12-01           0             0
# 1        2023-06-15           1             1
# 2        2019-02-08           1             1
# 3        2020-05-03           2             2
# 4        2021-08-02           3             1
# ...             ...         ...           ...
# 9995     2022-08-02           4             2
# 9996     2022-01-29           4             1
# 9997     2022-07-15           4             1
# 9998     2020-02-26           2             1
# 9999     2023-04-15           2             2
#
# [10000 rows x 12 columns]

# %%
df['Duration'] = (df['Discharge Date'] - df['Date of Admission']).dt.days
df[30:]
# Out:
#       Age  Gender  Blood Type  Medical Condition Date of Admission  \
# 30     37       1           2                  3        2021-11-09
# 31     81       0           5                  2        2023-07-09
# 32     78       0           0                  1        2021-02-06
# 33     51       0           2                  1        2021-01-29
# 34     33       0           6                  5        2019-12-01
# ...   ...     ...         ...                ...               ...
# 9995   83       0           4                  2        2022-07-29
# 9996   47       1           3                  3        2022-01-06
# 9997   54       0           2                  3        2022-07-01
# 9998   84       0           4                  3        2020-02-06
# 9999   20       0           2                  3        2023-03-22
#
#       Insurance Provider  Billing Amount  Room Number  Admission Type  \
# 30                     0           22356          456               1
# 31                     4           21001          197               1
# 32                     0            9007          247               2
# 33                     4           39031          228               0
# 34                     3           24609          137               1
# ...                  ...             ...          ...             ...
# 9995                   1           39606          110               0
# 9996                   4            5995          244               1
# 9997                   4           49559          312               0
# 9998                   1           25236          420               2
# 9999                   2           37223          290               1
#
#      Discharge Date  Medication  Test Results  Duration
# 30       2021-11-28           1             2        19
# 31       2023-07-17           1             1         8
# 32       2021-03-03           1             2        25
# 33       2021-02-23           3             2        25
# 34       2019-12-18           2             2        17
# ...             ...         ...           ...       ...
# 9995     2022-08-02           4             2         4
# 9996     2022-01-29           4             1        23
# 9997     2022-07-15           4             1        14
# 9998     2020-02-26           2             1        20
# 9999     2023-04-15           2             2        24
#
# [9970 rows x 13 columns]

# %%
df=df.drop(columns=['Date of Admission','Discharge Date'])

# %%
a=df.corr()
a
# Out:
#                          Age    Gender  Blood Type  Medical Condition  \
# Age                 1.000000  0.008099    0.011153          -0.008167
# Gender              0.008099  1.000000    0.018187          -0.000627
# Blood Type          0.011153  0.018187    1.000000          -0.005727
# Medical Condition  -0.008167 -0.000627   -0.005727           1.000000
# Insurance Provider -0.004987 -0.030543    0.022191          -0.009300
# Billing Amount     -0.009483 -0.002339    0.007112          -0.012880
# Room Number        -0.005371 -0.002864    0.006094           0.003493
# Admission Type      0.003233  0.004515    0.000778           0.005659
# Medication          0.003522  0.000111    0.006672           0.023598
# Test Results        0.003572 -0.017273   -0.004024           0.000446
# Duration            0.009111  0.006361   -0.005262          -0.000405
#
#                     Insurance Provider  Billing Amount  Room Number  \
# Age                          -0.004987       -0.009483    -0.005371
# Gender                       -0.030543       -0.002339    -0.002864
# Blood Type                    0.022191        0.007112     0.006094
# Medical Condition            -0.009300       -0.012880     0.003493
# Insurance Provider            1.000000        0.015340     0.011270
# Billing Amount                0.015340        1.000000    -0.006161
# Room Number                   0.011270       -0.006161     1.000000
# Admission Type               -0.004369        0.002531    -0.004711
# Medication                    0.023239       -0.017002     0.000877
# Test Results                  0.002515       -0.003936     0.003164
# Duration                     -0.004749       -0.013507     0.009610
#
#                     Admission Type  Medication  Test Results  Duration
# Age                       0.003233    0.003522      0.003572  0.009111
# Gender                    0.004515    0.000111     -0.017273  0.006361
# Blood Type                0.000778    0.006672     -0.004024 -0.005262
# Medical Condition         0.005659    0.023598      0.000446 -0.000405
# Insurance Provider       -0.004369    0.023239      0.002515 -0.004749
# Billing Amount            0.002531   -0.017002     -0.003936 -0.013507
# Room Number              -0.004711    0.000877      0.003164  0.009610
# Admission Type            1.000000    0.005903      0.003193 -0.005942
# Medication                0.005903    1.000000      0.005608  0.007922
# Test Results              0.003193    0.005608      1.000000  0.010311
# Duration                 -0.005942    0.007922      0.010311  1.000000

# %%
plt.figure(figsize=(20,20))
heatmap=sns.heatmap(a,annot=True)

# %%
sns.scatterplot(x='Age',y='Test Results',data=df,hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Test Results'>

# %%
sns.barplot(x='Age',y='Test Results',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Test Results'>
